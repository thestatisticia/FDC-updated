# %% [markdown]
# # Beginner Walkthrough Notebook
#
# This notebook mirrors the CLI tutorial and highlights where to find each beginner resource. Run through the steps, execute commands in your terminal, and take notes directly here.

# %% [markdown]
# ## Phase 1 – Quick Wins
#
# 1. **Bootstrap environment**
#    - Terminal: `yarn bootstrap:beginner --explain`
#    - Kumbuka kubadilisha `.env` baada ya amri kuisha.
# 2. **Playground scripts**
#    - Terminal: `yarn hardhat run scripts/playground/helloFdc.ts --network coston2 --dry-run --explain`
#    - Andika uelewa wako kwenye seli ifuatayo.
# 3. **Maswali ya mara kwa mara**
#    - Tazama `docs/kiswahili/faq.md` unapokutana na changamoto.

# %% [markdown]
# ## Phase 2 – Core Learning
#
# - Endesha `yarn tutorial:beginner -- --dry-run --explain` na ufuate maagizo.
# - Baada ya kila hatua, andika hapa ulichofahamu:
#
# > Maelezo ya kujifunza:
#
# ## Phase 3 – Advanced Tooling
#
# 1. Jaribu `utils/simpleFdc.ts` ndani ya mradi wako wenyewe.
# 2. Endesha majaribio: `yarn test`.
# 3. Tumia `utils/progress.ts` kuongeza maoni ya hali kwenye skripti zako.
#
# > Mahali pa kuboresha zaidi:
